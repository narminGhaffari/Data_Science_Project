# %% [markdown]
# # Data Set Description:

# %% [markdown]
# For the aim of this project, the coordinates of different neighborhoods of Berlin is the initial step. Having Latitude and Longitude information about each Postal code in Berlin, it would be easy to find out the different venues using foursquare.com within each neighborhood. Having this venues and using clustering, we will be able to find out the neighborhoods with higher similarities to the neighborhood of the first sucessful sport center of the owner.

# %% [markdown]
# The website geonames.org provides the all postal codes of Berlin with their corresponding Latitude and Longitude information. In the following you can see the first 5 rows of this data set.

# %%
# from IPython.display import Image
# Image(filename = '/Users/narminghaffarilaleh/Desktop/dataset.png')

# %% [markdown]
# The first sport center is located in Charlottenburg neighbourhood with the postal code of 14055. Using Foursqaure it would be possible to calculate the similarities between this area with other areas in Berlin and decide for the best location for another branch of it.
